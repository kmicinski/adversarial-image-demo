# %% [markdown]
# # Adversarial Image Classification with FGSM
# This notebook launches a simple Gradio interface around a pretrained ResNet-18. Upload an image, classify it, and use its input gradient to construct an adversarial example.

# %%
# !git clone https://github.com/YOUR-USERNAME/adversarial-image-demo.git
# %cd adversarial-image-demo
# !pip -q install -r requirements.txt

# %% [markdown]
# Before publishing the repository, replace `YOUR-USERNAME` above with the GitHub account or organization that hosts it. If you uploaded the repository files directly into the Colab session instead, skip the clone and change-directory lines.

# %%
from app import build_app
demo = build_app()
demo.launch(share=True, debug=True)
