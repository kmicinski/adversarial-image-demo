# %% [markdown]
# # Adversarial Image Classification with FGSM and PGD
# This notebook launches the Gradio comparison and its integrated code tutorial. Upload an image to compare a one-step FGSM attack with iterative PGD.

# %%
# !test -d adversarial-image-demo/.git && git -C adversarial-image-demo pull --ff-only || git clone https://github.com/kmicinski/adversarial-image-demo.git
# %cd /content/adversarial-image-demo
# !pip -q install -r requirements.txt

# %% [markdown]
# Rerun the setup cell when the repository changes. It updates an existing Colab checkout instead of continuing to use an older clone.

# %%
import importlib
import app
importlib.reload(app)  # Load edits even if app was imported earlier.
demo = app.build_app()
demo.launch(share=True, debug=True)
